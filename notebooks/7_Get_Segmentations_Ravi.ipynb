# %%
import sys 
import os
sys.path.append(os.path.relpath("../code/"))
from data import *
from model import *

# %%
import datetime

def get_input_data(ID,SLICE,PATH,WLD,IMG_WIDTH,IMG_HEIGHT,IMG_CHANNELS):
    X_test = np.zeros((1, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint16)
    dir_names = glob(PATH+ID+WLD)
    dir_names = natural_sort(dir_names)
    #1st ff, 2nd r2*, 3rd water, 4th fat
    #water ch = 0, ix = 2
    #fat ch = 1, ix = 3
    #ff ch = 2, ix = 0
    #r2* ch = 3, ix = 1
    def zero():
        return 0
    def one():
        return 1
    def two():
        return 2
    def three():
        return 3
    switcher = {
            0: two,
            1: three,
            2: zero,
            3: one
        }
    def ch_to_ix(argument):
        # Get the function from switcher dictionary
        func = switcher.get(argument, "nothing")
        # Execute the function
        return func()
    for ch in range(IMG_CHANNELS):
        dir_name = dir_names[ch_to_ix(ch)]
        _, ch_name = os.path.split(dir_name)
        path = glob(PATH+ID+'/'+ch_name+'/'+ID+'S'+ch_name+'I'+SLICE+'.DCM')
        img = dicom.read_file(path[0])
        img = (img.pixel_array).astype(np.int16)
        img = np.array(img, dtype=np.int16)[np.newaxis,:,:]
        X_test[:,:,:,ch] = img
    
    _, water_ch_name = os.path.split(dir_names[2])
    save_string = ID+'S'+water_ch_name+'I_mask_pred_'+SLICE+'.DCM'
    print('Done!')
    
    return X_test, save_string

def bytes_to_int(bytes):
    result = 0
    for b in bytes:
        result = result*256 + int(b)
    return result

# %%
json_file = open('../model/model-3.json','r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights('../model/model-3.h5')

model.compile(optimizer=Adam(lr = 1e-4), loss='binary_crossentropy', metrics=[dice_coef,'accuracy'])

width = 256
height = 256
slices = 20
channels = 4
DATA_PATH = '../data/ravi/'
save_path = '../dcm_data_rc/'

# %%
id_suffix = 'E5789'
wld = '/5*'
print(id_suffix)
files = glob(DATA_PATH + id_suffix + wld + '/*.DCM')
files = natural_sort(files)
if not os.path.exists(save_path+id_suffix):
    os.makedirs(save_path+id_suffix)
for file in files:
    slice_num = (file.split("I",1)[1]).split(".DCM",1)[0]
    (X_test, save_string) = get_input_data(id_suffix, slice_num, DATA_PATH, wld, width, height, channels)
    # Predict on each slice and save masks as DICOM using the same slice's mask's metadata
    preds_test = model.predict(X_test, verbose=1)
    #print(preds_test.shape)
    preds_test = preds_test.squeeze()
    # Threshold predictions
    preds_test_t = (preds_test > 0.5).astype(np.uint16)
    #print(preds_test_t.shape)
    #plt.imshow(preds_test_t, cmap='gray')
    #plt.show()
    ds = dicom.dcmread(file)
    #print(ds)
    """code_lines = code_file(file)
    exec(code_lines)
    # Set the transfer syntax
    ds.is_little_endian = True
    ds.is_implicit_VR = True"""
    # Set creation date/time
    dt = datetime.datetime.now()
    ds.ContentDate = dt.strftime('%Y%m%d')
    timeStr = dt.strftime('%H%M%S.%f')  # long format with micro seconds
    ds.ContentTime = timeStr
    # Change pixel data to predicted values
    ds.PixelData = preds_test_t.tobytes()
    print("Writing test file", save_string)
    filename = save_path + id_suffix + '/' + save_string
    ds.save_as(filename)
    print("File saved.")
    """print('Load file {} ...'.format(filename))
    ds = dicom.dcmread(filename)
    print(ds)"""
# Out:
# E5789
# Done!
# WARNING:tensorflow:From /home/jiamin/miniconda/envs/tf_gpu_cuda10/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 1/1 [==============================] - 1s 1s/step
# Writing test file E5789S501I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S501I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S501I_mask_pred_22.DCM
# File saved.

# %%
id_suffix = 'E5789'
wld = '/7*'
print(id_suffix)
files = glob(DATA_PATH + id_suffix + wld + '/*.DCM')
files = natural_sort(files)
if not os.path.exists(save_path+id_suffix):
    os.makedirs(save_path+id_suffix)
for file in files:
    slice_num = (file.split("I",1)[1]).split(".DCM",1)[0]
    (X_test, save_string) = get_input_data(id_suffix, slice_num, DATA_PATH, wld, width, height, channels)
    # Predict on each slice and save masks as DICOM using the same slice's mask's metadata
    preds_test = model.predict(X_test, verbose=1)
    #print(preds_test.shape)
    preds_test = preds_test.squeeze()
    # Threshold predictions
    preds_test_t = (preds_test > 0.5).astype(np.uint16)
    #print(preds_test_t.shape)
    #plt.imshow(preds_test_t, cmap='gray')
    #plt.show()
    ds = dicom.dcmread(file)
    #print(ds)
    """code_lines = code_file(file)
    exec(code_lines)
    # Set the transfer syntax
    ds.is_little_endian = True
    ds.is_implicit_VR = True"""
    # Set creation date/time
    dt = datetime.datetime.now()
    ds.ContentDate = dt.strftime('%Y%m%d')
    timeStr = dt.strftime('%H%M%S.%f')  # long format with micro seconds
    ds.ContentTime = timeStr
    # Change pixel data to predicted values
    ds.PixelData = preds_test_t.tobytes()
    print("Writing test file", save_string)
    filename = save_path + id_suffix + '/' + save_string
    ds.save_as(filename)
    print("File saved.")
    """print('Load file {} ...'.format(filename))
    ds = dicom.dcmread(filename)
    print(ds)"""
# Out:
# E5789
# Done!
# 1/1 [==============================] - 0s 6ms/step
# Writing test file E5789S701I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_25.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_26.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_27.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_28.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_29.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_30.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_31.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_32.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_33.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_34.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_35.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_36.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_37.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_38.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_39.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_40.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_41.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_42.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_43.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_44.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_45.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_46.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_47.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_48.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_49.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_50.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_25.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_26.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_27.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_28.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_29.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_30.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_31.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_32.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_33.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_34.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_35.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_36.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_37.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_38.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_39.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_40.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_41.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_42.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_43.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_44.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_45.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_46.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_47.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_48.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_49.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_50.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_25.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_26.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_27.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_28.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_29.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_30.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_31.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_32.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_33.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_34.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_35.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_36.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_37.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_38.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_39.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_40.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_41.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_42.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_43.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_44.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_45.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_46.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_47.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_48.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_49.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_50.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_25.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_26.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_27.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_28.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_29.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_30.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_31.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_32.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_33.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_34.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_35.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_36.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_37.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_38.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_39.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_40.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_41.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_42.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_43.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_44.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_45.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_46.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_47.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5789S701I_mask_pred_48.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_49.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5789S701I_mask_pred_50.DCM
# File saved.

# %%
id_suffix = 'E5790'
wld = '/5*'
print(id_suffix)
files = glob(DATA_PATH + id_suffix + wld + '/*.DCM')
files = natural_sort(files)
if not os.path.exists(save_path+id_suffix):
    os.makedirs(save_path+id_suffix)
for file in files:
    slice_num = (file.split("I",1)[1]).split(".DCM",1)[0]
    (X_test, save_string) = get_input_data(id_suffix, slice_num, DATA_PATH, wld, width, height, channels)
    # Predict on each slice and save masks as DICOM using the same slice's mask's metadata
    preds_test = model.predict(X_test, verbose=1)
    #print(preds_test.shape)
    preds_test = preds_test.squeeze()
    # Threshold predictions
    preds_test_t = (preds_test > 0.5).astype(np.uint16)
    #print(preds_test_t.shape)
    #plt.imshow(preds_test_t, cmap='gray')
    #plt.show()
    ds = dicom.dcmread(file)
    #print(ds)
    """code_lines = code_file(file)
    exec(code_lines)
    # Set the transfer syntax
    ds.is_little_endian = True
    ds.is_implicit_VR = True"""
    # Set creation date/time
    dt = datetime.datetime.now()
    ds.ContentDate = dt.strftime('%Y%m%d')
    timeStr = dt.strftime('%H%M%S.%f')  # long format with micro seconds
    ds.ContentTime = timeStr
    # Change pixel data to predicted values
    ds.PixelData = preds_test_t.tobytes()
    print("Writing test file", save_string)
    filename = save_path + id_suffix + '/' + save_string
    ds.save_as(filename)
    print("File saved.")
    """print('Load file {} ...'.format(filename))
    ds = dicom.dcmread(filename)
    print(ds)"""
# Out:
# E5790
# Done!
# 1/1 [==============================] - 0s 12ms/step
# Writing test file E5790S501I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S501I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S501I_mask_pred_18.DCM
# File saved.

# %%
id_suffix = 'E5790'
wld = '/7*'
print(id_suffix)
files = glob(DATA_PATH + id_suffix + wld + '/*.DCM')
files = natural_sort(files)
if not os.path.exists(save_path+id_suffix):
    os.makedirs(save_path+id_suffix)
for file in files:
    slice_num = (file.split("I",1)[1]).split(".DCM",1)[0]
    (X_test, save_string) = get_input_data(id_suffix, slice_num, DATA_PATH, wld, width, height, channels)
    # Predict on each slice and save masks as DICOM using the same slice's mask's metadata
    preds_test = model.predict(X_test, verbose=1)
    #print(preds_test.shape)
    preds_test = preds_test.squeeze()
    # Threshold predictions
    preds_test_t = (preds_test > 0.5).astype(np.uint16)
    #print(preds_test_t.shape)
    #plt.imshow(preds_test_t, cmap='gray')
    #plt.show()
    ds = dicom.dcmread(file)
    #print(ds)
    """code_lines = code_file(file)
    exec(code_lines)
    # Set the transfer syntax
    ds.is_little_endian = True
    ds.is_implicit_VR = True"""
    # Set creation date/time
    dt = datetime.datetime.now()
    ds.ContentDate = dt.strftime('%Y%m%d')
    timeStr = dt.strftime('%H%M%S.%f')  # long format with micro seconds
    ds.ContentTime = timeStr
    # Change pixel data to predicted values
    ds.PixelData = preds_test_t.tobytes()
    print("Writing test file", save_string)
    filename = save_path + id_suffix + '/' + save_string
    ds.save_as(filename)
    print("File saved.")
    """print('Load file {} ...'.format(filename))
    ds = dicom.dcmread(filename)
    print(ds)"""
# Out:
# E5790
# Done!
# 1/1 [==============================] - 0s 9ms/step
# Writing test file E5790S701I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5790S701I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5790S701I_mask_pred_18.DCM
# File saved.

# %%
id_suffix = 'E5822'
wld = '/6*'
print(id_suffix)
files = glob(DATA_PATH + id_suffix + wld + '/*.DCM')
files = natural_sort(files)
if not os.path.exists(save_path+id_suffix):
    os.makedirs(save_path+id_suffix)
for file in files:
    slice_num = (file.split("I",1)[1]).split(".DCM",1)[0]
    (X_test, save_string) = get_input_data(id_suffix, slice_num, DATA_PATH, wld, width, height, channels)
    # Predict on each slice and save masks as DICOM using the same slice's mask's metadata
    preds_test = model.predict(X_test, verbose=1)
    #print(preds_test.shape)
    preds_test = preds_test.squeeze()
    # Threshold predictions
    preds_test_t = (preds_test > 0.5).astype(np.uint16)
    #print(preds_test_t.shape)
    #plt.imshow(preds_test_t, cmap='gray')
    #plt.show()
    ds = dicom.dcmread(file)
    #print(ds)
    """code_lines = code_file(file)
    exec(code_lines)
    # Set the transfer syntax
    ds.is_little_endian = True
    ds.is_implicit_VR = True"""
    # Set creation date/time
    dt = datetime.datetime.now()
    ds.ContentDate = dt.strftime('%Y%m%d')
    timeStr = dt.strftime('%H%M%S.%f')  # long format with micro seconds
    ds.ContentTime = timeStr
    # Change pixel data to predicted values
    ds.PixelData = preds_test_t.tobytes()
    print("Writing test file", save_string)
    filename = save_path + id_suffix + '/' + save_string
    ds.save_as(filename)
    print("File saved.")
    """print('Load file {} ...'.format(filename))
    ds = dicom.dcmread(filename)
    print(ds)"""
# Out:
# E5822
# Done!
# 1/1 [==============================] - 0s 17ms/step
# Writing test file E5822S601I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S601I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S601I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S601I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S601I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S601I_mask_pred_24.DCM
# File saved.

# %%
id_suffix = 'E5822'
wld = '/10*'
print(id_suffix)
files = glob(DATA_PATH + id_suffix + wld + '/*.DCM')
files = natural_sort(files)
if not os.path.exists(save_path+id_suffix):
    os.makedirs(save_path+id_suffix)
for file in files:
    slice_num = (file.split("I",1)[1]).split(".DCM",1)[0]
    (X_test, save_string) = get_input_data(id_suffix, slice_num, DATA_PATH, wld, width, height, channels)
    # Predict on each slice and save masks as DICOM using the same slice's mask's metadata
    preds_test = model.predict(X_test, verbose=1)
    #print(preds_test.shape)
    preds_test = preds_test.squeeze()
    # Threshold predictions
    preds_test_t = (preds_test > 0.5).astype(np.uint16)
    #print(preds_test_t.shape)
    #plt.imshow(preds_test_t, cmap='gray')
    #plt.show()
    ds = dicom.dcmread(file)
    #print(ds)
    """code_lines = code_file(file)
    exec(code_lines)
    # Set the transfer syntax
    ds.is_little_endian = True
    ds.is_implicit_VR = True"""
    # Set creation date/time
    dt = datetime.datetime.now()
    ds.ContentDate = dt.strftime('%Y%m%d')
    timeStr = dt.strftime('%H%M%S.%f')  # long format with micro seconds
    ds.ContentTime = timeStr
    # Change pixel data to predicted values
    ds.PixelData = preds_test_t.tobytes()
    print("Writing test file", save_string)
    filename = save_path + id_suffix + '/' + save_string
    ds.save_as(filename)
    print("File saved.")
    """print('Load file {} ...'.format(filename))
    ds = dicom.dcmread(filename)
    print(ds)"""
# Out:
# E5822
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S1001I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S1001I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S1001I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 7ms/step
# Writing test file E5822S1001I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S1001I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S1001I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5822S1001I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5822S1001I_mask_pred_24.DCM
# File saved.

# %%
id_suffix = 'E5824'
wld = '/6*'
print(id_suffix)
files = glob(DATA_PATH + id_suffix + wld + '/*.DCM')
files = natural_sort(files)
if not os.path.exists(save_path+id_suffix):
    os.makedirs(save_path+id_suffix)
for file in files:
    slice_num = (file.split("I",1)[1]).split(".DCM",1)[0]
    (X_test, save_string) = get_input_data(id_suffix, slice_num, DATA_PATH, wld, width, height, channels)
    # Predict on each slice and save masks as DICOM using the same slice's mask's metadata
    preds_test = model.predict(X_test, verbose=1)
    #print(preds_test.shape)
    preds_test = preds_test.squeeze()
    # Threshold predictions
    preds_test_t = (preds_test > 0.5).astype(np.uint16)
    #print(preds_test_t.shape)
    #plt.imshow(preds_test_t, cmap='gray')
    #plt.show()
    ds = dicom.dcmread(file)
    #print(ds)
    """code_lines = code_file(file)
    exec(code_lines)
    # Set the transfer syntax
    ds.is_little_endian = True
    ds.is_implicit_VR = True"""
    # Set creation date/time
    dt = datetime.datetime.now()
    ds.ContentDate = dt.strftime('%Y%m%d')
    timeStr = dt.strftime('%H%M%S.%f')  # long format with micro seconds
    ds.ContentTime = timeStr
    # Change pixel data to predicted values
    ds.PixelData = preds_test_t.tobytes()
    print("Writing test file", save_string)
    filename = save_path + id_suffix + '/' + save_string
    ds.save_as(filename)
    print("File saved.")
    """print('Load file {} ...'.format(filename))
    ds = dicom.dcmread(filename)
    print(ds)"""
# Out:
# E5824
# Done!
# 1/1 [==============================] - 0s 9ms/step
# Writing test file E5824S601I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 5ms/step
# Writing test file E5824S601I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 6ms/step
# Writing test file E5824S601I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S601I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S601I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S601I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S601I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 5ms/step
# Writing test file E5824S601I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 6ms/step
# Writing test file E5824S601I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S601I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S601I_mask_pred_24.DCM
# File saved.

# %%
id_suffix = 'E5824'
wld = '/10*'
print(id_suffix)
files = glob(DATA_PATH + id_suffix + wld + '/*.DCM')
files = natural_sort(files)
if not os.path.exists(save_path+id_suffix):
    os.makedirs(save_path+id_suffix)
for file in files:
    slice_num = (file.split("I",1)[1]).split(".DCM",1)[0]
    (X_test, save_string) = get_input_data(id_suffix, slice_num, DATA_PATH, wld, width, height, channels)
    # Predict on each slice and save masks as DICOM using the same slice's mask's metadata
    preds_test = model.predict(X_test, verbose=1)
    #print(preds_test.shape)
    preds_test = preds_test.squeeze()
    # Threshold predictions
    preds_test_t = (preds_test > 0.5).astype(np.uint16)
    #print(preds_test_t.shape)
    #plt.imshow(preds_test_t, cmap='gray')
    #plt.show()
    ds = dicom.dcmread(file)
    #print(ds)
    """code_lines = code_file(file)
    exec(code_lines)
    # Set the transfer syntax
    ds.is_little_endian = True
    ds.is_implicit_VR = True"""
    # Set creation date/time
    dt = datetime.datetime.now()
    ds.ContentDate = dt.strftime('%Y%m%d')
    timeStr = dt.strftime('%H%M%S.%f')  # long format with micro seconds
    ds.ContentTime = timeStr
    # Change pixel data to predicted values
    ds.PixelData = preds_test_t.tobytes()
    print("Writing test file", save_string)
    filename = save_path + id_suffix + '/' + save_string
    ds.save_as(filename)
    print("File saved.")
    """print('Load file {} ...'.format(filename))
    ds = dicom.dcmread(filename)
    print(ds)"""
# Out:
# E5824
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_24.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_1.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_2.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_3.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_4.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_5.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_6.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_7.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_8.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_9.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_10.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_11.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_12.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_13.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_14.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_15.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_16.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 3ms/step
# Writing test file E5824S1001I_mask_pred_17.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_18.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_19.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_20.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_21.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_22.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_23.DCM
# File saved.
# Done!
# 1/1 [==============================] - 0s 4ms/step
# Writing test file E5824S1001I_mask_pred_24.DCM
# File saved.
